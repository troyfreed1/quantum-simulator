# %% [markdown]
# ### Quantum Computing Final Project
# #### By: Francisco, Troy, Mike

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime import SamplerV2 as Sampler
import matplotlib
import pylatexenc
from qiskit.visualization import plot_histogram
import numpy as np
import os


QiskitRuntimeService.save_account(
token="eNQoL8FbkBlhwK5aF2QZOe-Uhk-Kjj9ixgVdtsKdZuxv", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
instance="crn:v1:bluemix:public:quantum-computing:us-east:a/f48de553a51b45a6a1bdbf58d68f620f:381f8770-b139-4826-a8a1-16b617341154::", # Optional,
overwrite=True
)
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)

# %% [markdown]
# #### Test Connection
#
# This is where we test that we are connected to our quantum computing instance.

# %%
# Test connection to IBM Quantum
print("Testing IBM Quantum connection...")
print(f"\nConnected service instance: {service.active_account()['instance']}")
print(f"\nSelected backend: {backend.name}")
print(f"Backend status: {backend.status().status_msg}")
print(f"Number of qubits: {backend.num_qubits}")
print(f"Pending jobs: {backend.status().pending_jobs}")
# Out:
# Testing IBM Quantum connection...
#
# Connected service instance: crn:v1:bluemix:public:quantum-computing:us-east:a/f48de553a51b45a6a1bdbf58d68f620f:381f8770-b139-4826-a8a1-16b617341154::
#
# Selected backend: ibm_fez
# Backend status: active
# Number of qubits: 156
# Pending jobs: 0
#
# --- Available backends ---
#   - ibm_fez (156 qubits)
#   - ibm_torino (133 qubits)
#   - ibm_marrakesh (156 qubits)
